# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# After reading in the dataset, the 'Complete' column needs to be moved so that the train_test_split function is easier to deal with

# %%
enron = pd.read_pickle("./enron_cleaned_stops.pkl")
tags = pd.read_pickle("./pos_tags_stops.pkl")

# %%
column_complete = enron.pop('Complete')
enron.insert(0, 'Complete', column_complete)
enron.head()
# Out:
#                                             Complete  \
# 0  re confidential employee informationlenhart i ...
# 1  re personal and confidential compensation info...
# 2  fw western wholesale activities gas & power co...
# 3  fw western wholesale activities gas & power co...
# 4  fw western wholesale activities gas & power co...
#
#                                       Message-ID                 Date  \
# 0   <9831685.1075855725804.JavaMail.evans@thyme>  2001-03-15 14:45:00
# 1  <21041312.1075855725847.JavaMail.evans@thyme>  2001-03-15 14:11:00
# 2   <5907100.1075858639941.JavaMail.evans@thyme>  2001-06-20 17:04:51
# 3  <26625142.1075858639964.JavaMail.evans@thyme>  2001-06-20 17:09:00
# 4  <19730598.1075858642129.JavaMail.evans@thyme>  2001-08-09 12:30:58
#
#                                      From  \
# 0  frozenset({'phillip.allen@enron.com'})
# 1  frozenset({'phillip.allen@enron.com'})
# 2       frozenset({'k..allen@enron.com'})
# 3       frozenset({'k..allen@enron.com'})
# 4       frozenset({'k..allen@enron.com'})
#
#                                                   To  \
# 0                frozenset({'todd.burke@enron.com'})
# 1                frozenset({'kim.bolton@enron.com'})
# 2  frozenset({'matt.smith@enron.com', 'matthew.le...
# 3  frozenset({'matt.smith@enron.com', 'matthew.le...
# 4  frozenset({'matt.smith@enron.com', 'm..tholt@e...
#
#                                              Subject  \
# 0      Re: Confidential Employee Information/Lenhart
# 1  RE: PERSONAL AND CONFIDENTIAL COMPENSATION INF...
# 2  FW: Western Wholesale Activities - Gas & Power...
# 3  FW: Western Wholesale Activities - Gas & Power...
# 4  FW: Western Wholesale Activities - Gas & Power...
#
#                                               X-From  \
# 0                                    Phillip K Allen
# 1                                    Phillip K Allen
# 2  Allen, Phillip K. </O=ENRON/OU=NA/CN=RECIPIENT...
# 3  Allen, Phillip K. </O=ENRON/OU=NA/CN=RECIPIENT...
# 4  Allen, Phillip K. </O=ENRON/OU=NA/CN=RECIPIENT...
#
#                                                 X-To X-cc  X-bcc   ...     \
# 0                                         Todd Burke  NaN    NaN   ...
# 1                                         Kim Bolton  NaN    NaN   ...
# 2  Lenhart, Matthew </O=ENRON/OU=NA/CN=RECIPIENTS...  NaN    NaN   ...
# 3  Lenhart, Matthew </O=ENRON/OU=NA/CN=RECIPIENTS...  NaN    NaN   ...
# 4  Smith, Matt </O=ENRON/OU=NA/CN=RECIPIENTS/CN=M...  NaN    NaN   ...
#
#   Cat_10_level_1 Cat_10_level_2 Cat_10_weight Cat_11_level_1 Cat_11_level_2  \
# 0            NaN            NaN           NaN            NaN            NaN
# 1            NaN            NaN           NaN            NaN            NaN
# 2            NaN            NaN           NaN            NaN            NaN
# 3            NaN            NaN           NaN            NaN            NaN
# 4            NaN            NaN           NaN            NaN            NaN
#
#    Cat_11_weight  Cat_12_level_1  Cat_12_level_2  Cat_12_weight  labeled
# 0            NaN             NaN             NaN            NaN     True
# 1            NaN             NaN             NaN            NaN     True
# 2            NaN             NaN             NaN            NaN     True
# 3            NaN             NaN             NaN            NaN     True
# 4            NaN             NaN             NaN            NaN     True
#
# [5 rows x 52 columns]

# %% [markdown]
# # Split the dataset into a train and test set

# %%
# X = first 14 columns of the dataframe --> up to the user column
# y = the label columns. The remaining columns are all labels, except for the "labeled" column which is True for every sample.
train_X, test_X, train_y, test_y = train_test_split(enron.iloc[:, 0:15], enron.iloc[:, 16:-1], test_size=0.2)

train_X.head()
# Out:
#                                                Complete  \
# 1590  fw elements of draft administration electric b...
# 593   re sen. murkowski to address usaee conference ...
# 667   re aga what have they done for us terence h am...
# 1475  attorneyclient communicationconfidential and p...
# 1436  re philippe yes phillippe left to join a firm ...
#
#                                          Message-ID                 Date  \
# 1590  <20699227.1075858707306.JavaMail.evans@thyme>  2001-09-07 16:08:11
# 593    <2525896.1075846174289.JavaMail.evans@thyme>  2000-09-14 10:06:00
# 667    <9178621.1075846178624.JavaMail.evans@thyme>  2000-10-04 18:46:00
# 1475  <28068551.1075845243490.JavaMail.evans@thyme>  2001-06-07 23:07:58
# 1436  <18983797.1075858884478.JavaMail.evans@thyme>  2001-06-30 17:59:00
#
#                                        From  \
# 1590    frozenset({'john.shelk@enron.com'})
# 593    frozenset({'steven.kean@enron.com'})
# 667    frozenset({'steven.kean@enron.com'})
# 1475  frozenset({'barbara.gray@enron.com'})
# 1436   frozenset({'steven.kean@enron.com'})
#
#                                                      To  \
# 1590  frozenset({'stephen.burns@enron.com', 'richard...
# 593           frozenset({'cynthia.sandherr@enron.com'})
# 667              frozenset({'terence.thorn@enron.com'})
# 1475                  frozenset({'dan.hyvl@enron.com'})
# 1436                  frozenset({'cmculbe@us.ibm.com'})
#
#                                                 Subject  \
# 1590  FW: Elements of Draft Administration Electric ...
# 593   Re: Sen. Murkowski to Address USAEE Conference...
# 667                                             Re: AGA
# 1475  ATTORNEY/CLIENT COMMUNICATION//////CONFIDENTIA...
# 1436                                       Re: Philippe
#
#                                                  X-From  \
# 1590  Shelk, John </O=ENRON/OU=NA/CN=RECIPIENTS/CN=J...
# 593                                       Steven J Kean
# 667                                       Steven J Kean
# 1475  Gray, Barbara </O=ENRON/OU=NA/CN=RECIPIENTS/CN...
# 1436                                      Steven J Kean
#
#                                                    X-To  \
# 1590  Kean, Steven J. </O=ENRON/OU=NA/CN=RECIPIENTS/...
# 593                                    Cynthia Sandherr
# 667                                     Terence H Thorn
# 1475  Hyvl, Dan </O=ENRON/OU=NA/CN=RECIPIENTS/CN=NOT...
# 1436        Christopher Culberson  <cmculbe@us.ibm.com>
#
#                                                    X-cc  X-bcc  \
# 1590                                                NaN    NaN
# 593                                  Jeffrey A Shankman    NaN
# 667                                                 NaN    NaN
# 1475  Hodge, Jeffrey </O=ENRON/OU=NA/CN=RECIPIENTS/C...    NaN
# 1436                                                NaN    NaN
#
#                                                X-Folder   X-Origin  \
# 1590  \RSHAPIRO (Non-Privileged)\Shapiro, Richard\Fe...  Shapiro-R
# 593   \Steven_Kean_Dec2000_1\Notes Folders\All docum...     KEAN-S
# 667   \Steven_Kean_Dec2000_1\Notes Folders\All docum...     KEAN-S
# 1475         \Martin, Thomas A.\Martin, Thomas A.\Inbox   MARTIN-T
# 1436  \SKEAN (Non-Privileged)\Kean, Steven J.\Sent I...     Kean-S
#
#                          X-FileName  \
# 1590  RSHAPIRO (Non-Privileged).pst
# 593                       skean.nsf
# 667                       skean.nsf
# 1475          Martin, Thomas A..pst
# 1436     SKEAN (Non-Privileged).pst
#
#                                                 content       user
# 1590  The attached from EPSA is reportedly the detai...  shapiro-r
# 593   Cynthia, get back to Jeff on this. It doesn't ...     kean-s
# 667   What have they done for us? Terence H Thorn@EN...     kean-s
# 1475  Article II of the NONCOMPETITION AGREEMENT ent...   martin-t
# 1436  Yes, Phillippe left to join a firm in New York...     kean-s

# %% [markdown]
# # Supervised Models
